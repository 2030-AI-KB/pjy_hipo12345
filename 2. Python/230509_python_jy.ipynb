# %%
letter = 'o'
if letter == 'a' or letter == 'e' or letter == 'i' \
or letter == 'o' or letter == 'u':
    print(letter, 'is vowel')
else:
    print(letter, 'is not vowel')
# Out:
# o is vowel

# %%
vowels = 'aeiou'
letter = 'o'
if letter in vowels :
    print(letter, 'is vowels')
else:
    print(letter, 'is not vowels')
# Out:
# o is vowels

# %%
vowels = ['a', 'b', 'c', 'd']
letter = input("input matching : ")
if letter in vowels :
    print(letter, 'is vowels')
else:
    print(letter, 'is not vowels')
# Out:
# input matching : a
# a is vowels

# %%
vowels = ['I am a boy', 'I am a girl']
letter = input("input matching : ")
if letter in vowels :
    print(letter, 'is vowels')
else:
    print(letter, 'is not vowels')
# Out:
# input matching : I am a boy
# I am a boy is vowels

# %%
print('Give'+ 'us' + 'some' + 'space')
# Out:
# Giveussomespace

# %%
name = 'a.jpg'
print(name[1:])
name = 'P' + name[-4:]
print(name)
# Out:
# .jpg
# P.jpg

# %%
# 나는 이 세상에서 가장 행복하게 살기 위해 노력하는 행복 지킴이입니다.
# 라는 문장을 가지고 이 글을 작성한이가 중요하게 생각하는 영역을 찾아보세요
# 정량화 된 값을 도출하시어 설명해주십시요..
# 행복 이라는 키워드가 몇번 나오는지 세기
stc = '나는 이 세상에서 가장 행복하게 살기 위해 노력하는 행복 지킴이입니다.'
len(stc)
stc[:32]
word='행복'
stc.count(word)
# Out:
# 2

# %%
poem = '''How do I love thee? Let me count the ways.
I love thee to the depth and breadth and height
My soul can reach, when feeling out of sight
For the ends of Being and ideal Grace.
I love thee to the level of everyday's
Most quiet need, by sun and candle-light.
I love thee freely, as men strive for Right;
I love thee purely, as they turn from Praise.
I love thee with the passion put to use
In my old griefs, and with my childhood's faith.
I love thee with a love I seemed to lose
With my lost saint - I love thee with the breath,
Smiles, tears, of all my life! - and if God choose,
I shall but love thee better after death.'''
print(len(poem))
word1='love'
word2='soul'
word3='breath'
print(poem.count(word1))
print(poem.count(word2))
print(poem.count(word3))
# Out:
# 620
# 10
# 1
# 1

# %%
dist = poem.replace('?', '')
dist = poem.replace('-', '')
dist = poem.replace(',', '')
dist = poem.replace('.', '')
dist = poem.replace('!', '')
dist1 = dist.split()
dist2 = dist.split('\n')

dup = {}
for word in dist1:
    if word not in dup.keys():
        dup[word] = 1
    else:
        dup[word] += 1

print(dup)
# Out:
# {'How': 1, 'do': 1, 'I': 10, 'love': 10, 'thee?': 1, 'Let': 1, 'me': 1, 'count': 1, 'the': 6, 'ways.': 1, 'thee': 8, 'to': 4, 'depth': 1, 'and': 6, 'breadth': 1, 'height': 1, 'My': 1, 'soul': 1, 'can': 1, 'reach,': 1, 'when': 1, 'feeling': 1, 'out': 1, 'of': 4, 'sight': 1, 'For': 1, 'ends': 1, 'Being': 1, 'ideal': 1, 'Grace.': 1, 'level': 1, "everyday's": 1, 'Most': 1, 'quiet': 1, 'need,': 1, 'by': 1, 'sun': 1, 'candle-light.': 1, 'freely,': 1, 'as': 2, 'men': 1, 'strive': 1, 'for': 1, 'Right;': 1, 'purely,': 1, 'they': 1, 'turn': 1, 'from': 1, 'Praise.': 1, 'with': 4, 'passion': 1, 'put': 1, 'use': 1, 'In': 1, 'my': 4, 'old': 1, 'griefs,': 1, "childhood's": 1, 'faith.': 1, 'a': 1, 'seemed': 1, 'lose': 1, 'With': 1, 'lost': 1, 'saint': 1, '-': 2, 'breath,': 1, 'Smiles,': 1, 'tears,': 1, 'all': 1, 'life': 1, 'if': 1, 'God': 1, 'choose,': 1, 'shall': 1, 'but': 1, 'better': 1, 'after': 1, 'death.': 1}

# %%
# !pip install matplotlib.pyplot as plt
import matplotlib.pyplot as plt

x =[word for word in dup.keys()]
y =[word for word in dup.values()]
plt.figure(figsize=(100,20))
plt.bar(x,y, color='b', label='word')
plt.xlabel('Word', fontsize=30, color='w')
plt.ylabel('Count', fontsize=30, color='w')
plt.xticks(x, fontsize=22, color='r')
plt.title('Poem of Word Count',fontsize=50, color='black' )
plt.rcParams['axes.grid'] = True
plt.legend(loc=4)
plt.show()
# Out:
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
